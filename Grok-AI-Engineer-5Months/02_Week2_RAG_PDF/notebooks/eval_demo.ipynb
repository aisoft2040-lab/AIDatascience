# %%
# Week 2 – Evaluation Demo
from eval.metrics import precision_recall_f1, recall_at_k

def show(title, value):
    print(f"{title}: {value}")

# %%
# Cell 2: precision/recall/f1 demo
p, r, f1 = precision_recall_f1(tp=8, fp=2, fn=1)
show("precision, recall, f1", (p, r, f1))

# %%
# Cell 3: recall@k demo
gt = {"d1", "d3"}
ranked = ["d1", "d2", "d4", "d3"]
rec_k3 = recall_at_k(gt, ranked, k=3)
rec_k4 = recall_at_k(gt, ranked, k=4)
show("recall@3, recall@4", (rec_k3, rec_k4))
